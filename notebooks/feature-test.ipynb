# %%
root = 'feature-test'
name = 'feature-test'

title = 'Feature Test'
subtitle = 'Old Feature Test Page'
page = 5
isPublished = true

authors = 'yash101'

published = '2025-01-30T04:57:57.694Z'
lastModified = '2025-01-30T04:57:57.694Z'

# %% [markdown]
# This article is a feature test - tries to test different behaviors of Markdown, code and math.
#
# Is this section being rendered correctly? This Hero content was written with Markdown.
#
# ![image.png](attachment:40e6adab-c156-44a1-ab09-dc78d78cbfdf.png)

# %% [markdown]
# ## Jupyter Code Blocks
#
# ### Cell with successful output

# %%
# Code block and output

for i in range(5):
    print(f'Hello, {i}')

def hello_world():
    print('hello world')
# Out:
# Hello, 0
# Hello, 1
# Hello, 2
# Hello, 3
# Hello, 4

# %% [markdown]
# ### Code block with `stdout`, `stderr` and an Exception

# %%
# Stdout, stderr and runtime error

import sys

for i in range(10):
    if i % 2 == 0:
        print(f'Hello, {i}')
    else:
        print(f'Hello, {i}', file=sys.stderr)

x = None
x.doSomeMethodThatDoesNotExist()
# Out:
# Hello, 0
# Hello, 2
# Hello, 4
# Hello, 6
# Hello, 8
# Hello, 1
# Hello, 3
# Hello, 5
# Hello, 7
# Hello, 9
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#       9         print(f'Hello, {i}', file=sys.stderr)
#      11 x = None
# ---> 12 x.doSomeMethodThatDoesNotExist()
#
# AttributeError: 'NoneType' object has no attribute 'doSomeMethodThatDoesNotExist'

# %% [markdown]
# ### Code cell with Pyplot display and Pandas Table

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate random data for a plot
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(scale=0.1, size=len(x))

plt.figure(figsize=(8, 5))
plt.plot(x, y, label="Noisy Sine Wave", color="blue", linewidth=2)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Sample Matplotlib Plot")
plt.legend()
plt.grid(True)
plt.show()

# Generate a sample DataFrame
data = {
    "A": np.random.randint(0, 100, 10),
    "B": np.random.rand(10),
    "C": np.random.choice(["Yes", "No"], 10),
}
df = pd.DataFrame(data)

# Display DataFrame
df
# Out:
#     A         B    C
# 0  42  0.563690  Yes
# 1  83  0.158875  Yes
# 2  63  0.461055  Yes
# 3  85  0.535424  Yes
# 4  59  0.870812  Yes
# 5  41  0.623846   No
# 6  20  0.049943   No
# 7  60  0.206974   No
# 8  49  0.563570   No
# 9  72  0.964520   No

# %% [markdown]
# ### Escaping HTML in code blocks

# %%
print('<h1>Hello world!</h1>')
print('<h1>Hello world!</h1>')
# Out:
# <h1>Hello world!</h1>
# <h1>Hello world!</h1>

# %% [markdown]
# ## Markdown
#
# Tests on Markdown features

# %% [markdown]
# ### Headings:
#
# # Top level heading (h1)
#
# ## Heading h2
#
# ### Heading h3
#
# #### Heading h4
#
#
# ##### Heading h5
#
# ###### Heading h6

# %% [markdown]
# ### Bullet Points, Nested bullet points
#
# * Bullet point 1
# * Bullet point 2
#     * Nested bullet point 2.1
#         * Nested bullet point 2.1.1
#         * Nested bullet point 2.1.2
# * Bullet point 3

# %% [markdown]
# ### Numeric Lists
#
# 1. Bullet point 1
# 2. Bullet point 2
#     1. Bullet point 2.1
#     2. Bullet point 2.2
#         1. Bullet point 2.2.1
#         2. Bullet point 2.2.2
# 3. Bullet point 3
# 4. Bullet point 4

# %% [markdown]
# ### Task List (Currently unsupported)
#
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media

# %% [markdown]
# ### Code Blocks (inline and block)
#
# Hello world, `this is a code block`. Lorem ipsum dolor sit amet, co`nsectet`ur adipiscing elit.
#
# Code block without language description:
#
# ```
# function extractAttachments(blob) {
#   const attachments = Object
#     .entries(blob)
#     .map(([identifier, attachment]) => {
#       const mime = Object.keys(attachment)[0];
#       const data = Buffer.from(attachment[mime], 'base64');
#       const meta = probe.sync(data);
#
#       return {
#         identifier,
#         meta,
#         data,
#       };
#     });
#
#   return attachments;
# }
#
# ```
#
# Code block with language description:
#
# ```python
# function extractAttachments(blob) {
#   const attachments = Object
#     .entries(blob)
#     .map(([identifier, attachment]) => {
#       const mime = Object.keys(attachment)[0];
#       const data = Buffer.from(attachment[mime], 'base64');
#       const meta = probe.sync(data);
#
#       return {
#         identifier,
#         meta,
#         data,
#       };
#     });
#
#   return attachments;
# }
# ```

# %% [markdown]
# ### Math
#
# Inline equation $\lim_{n \to \infty} \sum_{k=1}^{n} \int_0^1 \frac{d}{dx} \left( e^{-x^2} \cos\left(\pi k x\right) \right) dx + \prod_{m=1}^{\infty} \left( 1 + \frac{1}{m^2} \right) + \oint_{\gamma} \frac{z^n}{(z-a)(z-b)} dz = \left[\begin{array}{ccc}\int_0^\pi\sin(x)dx & \sum_{k=1}^{\infty} \frac{1}{k^2} & \zeta(3) \\e^{i\pi} + 1 & \Gamma(n) & \lim_{x \to 0} \frac{\sin x}{x} \\\sqrt[3]{\frac{a+b}{c}} & \log\left(1 + \sum_{n=1}^{\infty} \frac{(-1)^n}{n} \right) & \det\left( \begin{array}{cc} 1 & 2 \\ 3 & 4\end{array} \right)\end{array}\right]$ - yeah that was complexicated
#
#
# Display math:
#
# $$
# \lim_{n \to \infty} \sum_{k=1}^{n} \int_0^1 \frac{d}{dx} \left( e^{-x^2} \cos\left(\pi k x\right) \right) dx
# + \prod_{m=1}^{\infty} \left( 1 + \frac{1}{m^2} \right)
# + \oint_{\gamma} \frac{z^n}{(z-a)(z-b)} dz
# =
# \left[
# \begin{array}{ccc}
# \int_0^\pi \sin(x) dx & \sum_{k=1}^{\infty} \frac{1}{k^2} & \zeta(3) \\
# e^{i\pi} + 1 & \Gamma(n) & \lim_{x \to 0} \frac{\sin x}{x} \\
# \sqrt[3]{\frac{a+b}{c}} & \log\left(1 + \sum_{n=1}^{\infty} \frac{(-1)^n}{n} \right) & \det\left( \begin{array}{cc} 1 & 2 \\ 3 & 4 \end{array} \right)
# \end{array}
# \right]
# $$

# %% [markdown]
# ### Images
#
# ![An Alien Civilization](attachment:8107510a-e0ea-40f5-9415-591ca8bd9ab3.webp)
#
# <img src="attachment:8107510a-e0ea-40f5-9415-591ca8bd9ab3.webp" alt="Another alien civilization" width="300" height="200" />
